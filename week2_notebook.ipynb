# %%
student_name = "Maisha"
student_id = "2410994829"  
print("Student name: " + student_name)
print("Student ID: " + student_id)
# Out:
# Student name: Maisha
# Student ID: 2410994829

# %%
import random
import matplotlib.pyplot as plt

n_values = 100
y_values = []

# Create data (y_values) randomly between 1 and 100.
for i in range(n_values):
    y_values.append(random.randint(1, 100))

x_values = range(n_values)  # X is sequence of values 0-99
plt.plot(x_values, y_values)
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
n_values = 100
y_values_1 = []
y_values_2 = []

# Create data (y_values) randomly between 1 and 100.
for i in range(n_values):
    y_values_1.append(random.randint(1, 100))
    y_values_2.append(random.randint(1, 100))

x_values = range(n_values)  # X is sequence of values 0-99
plt.plot(x_values, y_values_1)
plt.plot(x_values, y_values_2)  # call plot again draws in the same graph.
plt.show()

# %%
n_values = 1000
y_values_1 = []

prev_value_1 = 1 
for i in range(n_values):
    prev_value_1 += 1 
    y_values_1.append(prev_value_1)

x_values = range(n_values)
plt.plot(x_values, y_values_1, label="Line 1 (Increment by 1)")
plt.legend()
plt.show()

# %%
n_values = 1000
y_values_1 = []

prev_value_1 = 1000 
for i in range(n_values):
    prev_value_1 -= 1 
    y_values_1.append(prev_value_1)

x_values = range(n_values)
plt.plot(x_values, y_values_1, label="Line 1 (Decrement by 1)")
plt.legend()
plt.show()

# %%
import math
import matplotlib.pyplot as plt

n_values = 100
x_values = range(n_values)  # X values will be from 0 to 99

# Create wave-like data using the sin function
y_values_wave = [math.sin(0.1 * x) for x in x_values]  # 0.1 * x to control the wave frequency

plt.plot(x_values, y_values_wave, label="sin Wave")
plt.legend()
plt.show()
